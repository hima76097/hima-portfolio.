# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\hk760\Downloads\6. India Census 2011 (1).csv")
data.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %% [markdown]
# HOW WILL YOU HIDE THE INDEXES OF THE DATAFRAME?

# %%
data.head(2).style.hide_index()
# Out:
# C:\Users\hk760\AppData\Local\Temp\ipykernel_11724\2117454653.py:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   data.head(2).style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_9b342">
#   <thead>
#     <tr>
#       <th id="T_9b342_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_9b342_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_9b342_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_9b342_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_9b342_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_9b342_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_9b342_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_9b342_level0_col7" class="col_heading level0 col7" >Workers</th>
# ...

# %% [markdown]
# HOW CAN WE SET THE CAPTION/HEADING ON THE DATAFRAME?

# %%
data.head(2).style.set_caption("INDIA CENSUS 2011 DATASET")
# Out:
# <style type="text/css">
# </style>
# <table id="T_4ebc6">
#   <caption>INDIA CENSUS 2011 DATASET</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ebc6_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_4ebc6_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_4ebc6_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_4ebc6_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_4ebc6_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_4ebc6_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_4ebc6_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_4ebc6_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_4ebc6_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
# ...

# %% [markdown]
# SHOW THE RECORDS RELATED WITH THE DISTRICTS- NEW DELHI, LUCKNOW,JAIPUR

# %%
data[data['District_name'].isin(['New Delhi','Lucknow','Jaipur'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# CALCULATE STATE WISE: A) TOTAL NUMBER OF POPULATION
#                       B) TOTAL NUMBER OF POPULATION WITH DIFFERENT RELIGIONS

# %%
data.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
data.groupby('State_name').Population.sum().sort_values()
# Out:
# State_name
# LAKSHADWEEP                        64473
# DAMAN AND DIU                     243247
# DADRA AND NAGAR HAVELI            343709
# ANDAMAN AND NICOBAR ISLANDS       380581
# SIKKIM                            610577
# CHANDIGARH                       1055450
# MIZORAM                          1097206
# PONDICHERRY                      1247953
# ARUNACHAL PRADESH                1383727
# GOA                              1458545
# NAGALAND                         1978502
# MANIPUR                          2855794
# MEGHALAYA                        2966889
# TRIPURA                          3673917
# HIMACHAL PRADESH                 6864602
# UTTARAKHAND                     10086292
# JAMMU AND KASHMIR               12541302
# NCT OF DELHI                    16787941
# HARYANA                         25351462
# CHHATTISGARH                    25545198
# PUNJAB                          27743338
# ASSAM                           31205576
# ...

# %%
data.groupby('State_name')['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains'].sum()
# Out:
# C:\Users\hk760\AppData\Local\Temp\ipykernel_11724\151641833.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('State_name')['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains'].sum()
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# ANDHRA PRADESH                74824149   8082412     1129784     40244
# ARUNACHAL PRADESH               401876     27045      418732      3287
# ASSAM                         19180759  10679345     1165867     20672
# BIHAR                         86078686  17557809      129247     23779
# CHANDIGARH                      852574     51447        8720    138329
# CHHATTISGARH                  23819789    514998      490542     70036
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# ...

# %% [markdown]
# HOW MANY MALE WORKERS WERE THERE IN MAHARASHTRA STATE?

# %%
data[data.State_name == 'MAHARASHTRA']['Male_Workers'].sum()
# Out:
# 32616875

# %% [markdown]
# HOW TO SET A COLUMN AS INDEX OF THE DATAFRAME?

# %%
data.set_index('District_code')
# Out:
#                                 State_name              District_name  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Population    Male  Female  Literate  Workers  Male_Workers  \
# District_code
# ...

# %% [markdown]
# ADD A SUFFIX AND PREFIX TO THE COLUMN NAME.

# %%
data.add_suffix('right')
# Out:
#      District_coderight              State_nameright  \
# 0                     1            JAMMU AND KASHMIR
# 1                     2            JAMMU AND KASHMIR
# 2                     3            JAMMU AND KASHMIR
# 3                     4            JAMMU AND KASHMIR
# 4                     5            JAMMU AND KASHMIR
# ..                  ...                          ...
# 635                 636                  PONDICHERRY
# 636                 637                  PONDICHERRY
# 637                 638  ANDAMAN AND NICOBAR ISLANDS
# 638                 639  ANDAMAN AND NICOBAR ISLANDS
# 639                 640  ANDAMAN AND NICOBAR ISLANDS
#
#             District_nameright  Populationright  Maleright  Femaleright  \
# 0                      Kupwara           870354     474190       396164
# 1                       Badgam           753745     398041       355704
# 2                  Leh(Ladakh)           133487      78971        54516
# ...

# %%
data.add_prefix('left')
# Out:
#      leftDistrict_code               leftState_name  \
# 0                    1            JAMMU AND KASHMIR
# 1                    2            JAMMU AND KASHMIR
# 2                    3            JAMMU AND KASHMIR
# 3                    4            JAMMU AND KASHMIR
# 4                    5            JAMMU AND KASHMIR
# ..                 ...                          ...
# 635                636                  PONDICHERRY
# 636                637                  PONDICHERRY
# 637                638  ANDAMAN AND NICOBAR ISLANDS
# 638                639  ANDAMAN AND NICOBAR ISLANDS
# 639                640  ANDAMAN AND NICOBAR ISLANDS
#
#              leftDistrict_name  leftPopulation  leftMale  leftFemale  \
# 0                      Kupwara          870354    474190      396164
# 1                       Badgam          753745    398041      355704
# 2                  Leh(Ladakh)          133487     78971       54516
# ...
